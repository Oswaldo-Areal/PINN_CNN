# %% [markdown]
# ##Workshop da Escola de Verão do Laboratório Nacional de Computação Científica (LNCC)
#
# ###Mini-curso: Assimilação de Dados por Aprendizado de Máquina
#
#
# ####Neste notebook iremos desenvolver um modelo de Assimilação de Dados de Temperautua baseado em Aprendizado de Máquina.
#
# ####Para isso, carregaremos um conjunto de dados de observação e treinaremos um algoritmo baseado em Árvores de Decisão e *Boosting*, uma técnica baseada em aprendizado por *ensemble*.
#
# ![xgboost_illustration.png](data:image/png;base64,...)

# %% [markdown]
# ##Instalações necessárias

# %%
# !pip install cartopy

# %% [markdown]
# ##Importações dos pacotes necessários

# %%
import os
import datetime
import numpy as np
import pandas as pd
import xgboost as xgb
from scipy import signal
import cartopy.crs as ccrs
from sklearn.utils import shuffle
import cartopy.feature as cfeature
import cartopy.mpl.ticker as cticker
from matplotlib import pyplot as plt
from matplotlib import colorbar, colors
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ##Funções auxiliares

# %%
def expand(dataframe, coluna, variavel):
  result = {}
  for i in dataframe[variavel].unique():
    coluna_resutl = dataframe.loc[dataframe[variavel] == i][coluna].to_numpy()
    result[int(i)] = coluna_resutl

  return result

def plot(longi, lat, data, title, x=(-58.9,-47.699), y=(-36.2,-25.1),
         figsize=(10,8.5)):

    fig = plt.figure(figsize=figsize)

    # Set the axes using the specified map projection
    ax=plt.axes(projection=ccrs.PlateCarree())

    # Make a filled contour plot
    cs=ax.contourf(longi.T, lat.T, data.T,
                transform = ccrs.PlateCarree(),cmap='jet',extend='both')

    ax.coastlines()
    states = cfeature.NaturalEarthFeature(
                category='cultural',
                name='admin_0_boundary_lines_land', #admin_1_states_provinces - admin_0_boundary_lines_land
                scale='10m',
                facecolor='none',
                edgecolor='black')

    cbar = plt.colorbar(cs,shrink=0.5,orientation='vertical',
                        label='Temperatura 2M')
    ax.add_feature(states, linewidth=2, edgecolor="black")
    ax.add_feature(cfeature.LAND)

    ax.set_xlim(x)
    ax.set_ylim(y)
    ax.coastlines()
    ax.set_title(title)

# %% [markdown]
# ##Download dos dados

# %%
# !gdown https://drive.google.com/uc?id=1_RHG_Gos-EDP5w0CoNXlrWDXsawtN9br
# !gdown https://drive.google.com/uc?id=1KnMf7PMn8ZTZfD0-HF8BjoMltZS4l5Bw
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1_RHG_Gos-EDP5w0CoNXlrWDXsawtN9br
# From (redirected): https://drive.google.com/uc?id=1_RHG_Gos-EDP5w0CoNXlrWDXsawtN9br&confirm=t&uuid=088702fb-2320-419d-9279-d963d9ff3049
# To: /content/test.csv
# 100% 183M/183M [00:04<00:00, 42.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1KnMf7PMn8ZTZfD0-HF8BjoMltZS4l5Bw
# From (redirected): https://drive.google.com/uc?id=1KnMf7PMn8ZTZfD0-HF8BjoMltZS4l5Bw&confirm=t&uuid=8f0f45b1-6dd3-4f81-86cb-58b461cf7d88
# To: /content/train.csv
# 100% 177M/177M [00:01<00:00, 92.4MB/s]

# %% [markdown]
# ##Lendo conjuntos de treino e teste

# %%
PATH="/content/"

#treino
df_train = pd.read_csv(PATH+'train.csv', header=0)
df_train = df_train.drop(columns=['Unnamed: 0'], axis=1)

#teste
df_test = pd.read_csv(PATH+'test.csv', header=0)
df_test = df_test.drop(columns=['Unnamed: 0'], axis=1)

print(df_train.shape)
print(df_test.shape)
# Out:
# (1577928, 10)
# (1649652, 10)

# %%
df_train.head()
# Out:
#          LAT       LONG  PONTO DE GRADE Y  PONTO DE GRADE X  VAL. SIMULACAO  \
# 0 -36.198620 -59.649200               1.0               1.0      289.802551
# 1 -36.202236 -59.549255               1.0               2.0      289.662781
# 2 -36.205776 -59.449310               1.0               3.0      289.448120
# 3 -36.209244 -59.349365               1.0               4.0      289.283569
# 4 -36.212631 -59.249420               1.0               5.0      289.022247
#
#    VALOR DE OBSERVACAO   ANO     TARGET  MES  DIA
# 0           289.802551  2017  289.33725    7   28
# 1           289.662781  2017  289.26273    7   28
# 2           289.448120  2017  289.05374    7   28
# 3           289.283569  2017  288.91327    7   28
# 4           291.700010  2017  288.60556    7   28

# %%
df_train['LAT'].min(), df_train['LAT'].max()
# Out:
# (-36.28812026977539, -24.93133544921875)

# %%
df_train['MES'].unique(), df_train['ANO'].unique()
# Out:
# (array([7, 6, 8]), array([2017]))

# %%
ativacao_dia_teste = df_train[(df_train['MES'] == 7) & (df_train['DIA'] == 6)]

lat = expand(ativacao_dia_teste, 'LAT', variavel='PONTO DE GRADE Y')
lat = pd.DataFrame(lat)

longi = expand(ativacao_dia_teste, 'LONG', variavel='PONTO DE GRADE Y')
longi = pd.DataFrame(longi)

rotulos = expand(ativacao_dia_teste, 'TARGET', variavel='PONTO DE GRADE Y')
rotulos = pd.DataFrame(rotulos)

plot(longi, lat, rotulos, 'Análise 3DVar', x=(-58.9,-47.699), y=(-36.2,-25.1),
     figsize=(10,8.5))
# Out:
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %%
lat.values.min(), lat.values.max()
# Out:
# (-36.28812026977539, -24.93133544921875)

# %% [markdown]
# ##Conjunto de treino e validação

# %%
df_val = df_train[df_train['MES'] == 8]
df_train = df_train[df_train['MES'] <= 7]

# %%
y_train = df_train['TARGET'].copy()
X_train = df_train[['LAT', 'LONG', 'PONTO DE GRADE Y', 'PONTO DE GRADE X',
                    'VAL. SIMULACAO', 'VALOR DE OBSERVACAO', 'MES', 'DIA']].copy()
X_train.head()
# Out:
#          LAT       LONG  PONTO DE GRADE Y  PONTO DE GRADE X  VAL. SIMULACAO  \
# 0 -36.198620 -59.649200               1.0               1.0      289.802551
# 1 -36.202236 -59.549255               1.0               2.0      289.662781
# 2 -36.205776 -59.449310               1.0               3.0      289.448120
# 3 -36.209244 -59.349365               1.0               4.0      289.283569
# 4 -36.212631 -59.249420               1.0               5.0      289.022247
#
#    VALOR DE OBSERVACAO  MES  DIA
# 0           289.802551    7   28
# 1           289.662781    7   28
# 2           289.448120    7   28
# 3           289.283569    7   28
# 4           291.700010    7   28

# %%
y_val = df_val['TARGET'].copy()
X_val = df_val[['LAT', 'LONG', 'PONTO DE GRADE Y', 'PONTO DE GRADE X',
                    'VAL. SIMULACAO', 'VALOR DE OBSERVACAO', 'MES', 'DIA']].copy()
X_val.head()
# Out:
#               LAT       LONG  PONTO DE GRADE Y  PONTO DE GRADE X  \
# 107586 -36.198620 -59.649200               1.0               1.0
# 107587 -36.202236 -59.549255               1.0               2.0
# 107588 -36.205776 -59.449310               1.0               3.0
# 107589 -36.209244 -59.349365               1.0               4.0
# 107590 -36.212631 -59.249420               1.0               5.0
#
#         VAL. SIMULACAO  VALOR DE OBSERVACAO  MES  DIA
# 107586      285.153107           285.153107    8   18
# 107587      285.132874           285.132874    8   18
# 107588      285.079285           285.079285    8   18
# 107589      285.012360           285.012360    8   18
# 107590      284.995575           286.799990    8   18

# %% [markdown]
# ##Conjunto de teste

# %%
y_test = df_test['TARGET'].copy()
X_test = df_test[['LAT', 'LONG', 'PONTO DE GRADE Y', 'PONTO DE GRADE X',
                    'VAL. SIMULACAO', 'VALOR DE OBSERVACAO', 'MES', 'DIA']].copy()
X_test.head()
# Out:
#          LAT       LONG  PONTO DE GRADE Y  PONTO DE GRADE X  VAL. SIMULACAO  \
# 0 -36.198620 -59.649200               1.0               1.0      280.371643
# 1 -36.202236 -59.549255               1.0               2.0      280.334778
# 2 -36.205776 -59.449310               1.0               3.0      280.300171
# 3 -36.209244 -59.349365               1.0               4.0      280.277283
# 4 -36.212631 -59.249420               1.0               5.0      280.279175
#
#    VALOR DE OBSERVACAO  MES  DIA
# 0           280.371643    8   16
# 1           280.334778    8   16
# 2           280.300171    8   16
# 3           280.277283    8   16
# 4           281.399990    8   16

# %% [markdown]
# ###Treinamento do algoritmo -  XGBoost

# %%
my_model = xgb.XGBRegressor(objective='reg:squarederror',
                            n_estimators = 1000,
                            max_depth = 5)

evalset = [(X_train[['VAL. SIMULACAO', 'VALOR DE OBSERVACAO']].values,
            y_train.values),
           (X_val[['VAL. SIMULACAO', 'VALOR DE OBSERVACAO']].values,
            y_val.values)]

trained_model = my_model.fit(X_train[['VAL. SIMULACAO', 'VALOR DE OBSERVACAO']].values,
                             y_train.values, early_stopping_rounds=10,
            eval_set=evalset, verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:3.42520	validation_1-rmse:3.38538
# [1]	validation_0-rmse:2.41769	validation_1-rmse:2.45756
# [2]	validation_0-rmse:1.71910	validation_1-rmse:1.80169
# [3]	validation_0-rmse:1.24025	validation_1-rmse:1.35765
# [4]	validation_0-rmse:0.91789	validation_1-rmse:1.06394
# [5]	validation_0-rmse:0.70810	validation_1-rmse:0.88271
# [6]	validation_0-rmse:0.57790	validation_1-rmse:0.76495
# [7]	validation_0-rmse:0.50181	validation_1-rmse:0.69399
# [8]	validation_0-rmse:0.45990	validation_1-rmse:0.65208
# [9]	validation_0-rmse:0.43787	validation_1-rmse:0.62743
# [10]	validation_0-rmse:0.42663	validation_1-rmse:0.61266
# [11]	validation_0-rmse:0.42097	validation_1-rmse:0.60506
# [12]	validation_0-rmse:0.41815	validation_1-rmse:0.60007
# [13]	validation_0-rmse:0.41668	validation_1-rmse:0.59706
# [14]	validation_0-rmse:0.41591	validation_1-rmse:0.59532
# [15]	validation_0-rmse:0.41551	validation_1-rmse:0.59261
# [16]	validation_0-rmse:0.41528	validation_1-rmse:0.59091
# [17]	validation_0-rmse:0.41515	validation_1-rmse:0.59026
# [18]	validation_0-rmse:0.41506	validation_1-rmse:0.58953
# [19]	validation_0-rmse:0.41501	validation_1-rmse:0.58876
# [20]	validation_0-rmse:0.41497	validation_1-rmse:0.58863
# [21]	validation_0-rmse:0.41493	validation_1-rmse:0.58863
# [22]	validation_0-rmse:0.41491	validation_1-rmse:0.58829
# [23]	validation_0-rmse:0.41489	validation_1-rmse:0.58804
# [24]	validation_0-rmse:0.41487	validation_1-rmse:0.58800
# [25]	validation_0-rmse:0.41483	validation_1-rmse:0.58794
# [26]	validation_0-rmse:0.41481	validation_1-rmse:0.58751
# [27]	validation_0-rmse:0.41480	validation_1-rmse:0.58722
# [28]	validation_0-rmse:0.41478	validation_1-rmse:0.58720
# [29]	validation_0-rmse:0.41476	validation_1-rmse:0.58714
# [30]	validation_0-rmse:0.41475	validation_1-rmse:0.58714
# [31]	validation_0-rmse:0.41473	validation_1-rmse:0.58713
# [32]	validation_0-rmse:0.41472	validation_1-rmse:0.58694
# [33]	validation_0-rmse:0.41470	validation_1-rmse:0.58690
# [34]	validation_0-rmse:0.41467	validation_1-rmse:0.58692
# [35]	validation_0-rmse:0.41467	validation_1-rmse:0.58692
# [36]	validation_0-rmse:0.41464	validation_1-rmse:0.58692
# [37]	validation_0-rmse:0.41462	validation_1-rmse:0.58689
# [38]	validation_0-rmse:0.41461	validation_1-rmse:0.58692
# [39]	validation_0-rmse:0.41460	validation_1-rmse:0.58692
# [40]	validation_0-rmse:0.41459	validation_1-rmse:0.58691
# [41]	validation_0-rmse:0.41459	validation_1-rmse:0.58676
# [42]	validation_0-rmse:0.41458	validation_1-rmse:0.58677
# [43]	validation_0-rmse:0.41456	validation_1-rmse:0.58675
# [44]	validation_0-rmse:0.41454	validation_1-rmse:0.58675
# [45]	validation_0-rmse:0.41453	validation_1-rmse:0.58671
# [46]	validation_0-rmse:0.41452	validation_1-rmse:0.58670
# [47]	validation_0-rmse:0.41452	validation_1-rmse:0.58661
# [48]	validation_0-rmse:0.41451	validation_1-rmse:0.58661
# [49]	validation_0-rmse:0.41451	validation_1-rmse:0.58661
# [50]	validation_0-rmse:0.41449	validation_1-rmse:0.58659
# [51]	validation_0-rmse:0.41446	validation_1-rmse:0.58658
# [52]	validation_0-rmse:0.41445	validation_1-rmse:0.58658
# [53]	validation_0-rmse:0.41444	validation_1-rmse:0.58656
# [54]	validation_0-rmse:0.41443	validation_1-rmse:0.58657
# [55]	validation_0-rmse:0.41443	validation_1-rmse:0.58654
# [56]	validation_0-rmse:0.41443	validation_1-rmse:0.58648
# [57]	validation_0-rmse:0.41442	validation_1-rmse:0.58647
# [58]	validation_0-rmse:0.41442	validation_1-rmse:0.58647
# [59]	validation_0-rmse:0.41441	validation_1-rmse:0.58646
# [60]	validation_0-rmse:0.41440	validation_1-rmse:0.58646
# [61]	validation_0-rmse:0.41439	validation_1-rmse:0.58645
# [62]	validation_0-rmse:0.41438	validation_1-rmse:0.58644
# [63]	validation_0-rmse:0.41436	validation_1-rmse:0.58644
# [64]	validation_0-rmse:0.41435	validation_1-rmse:0.58643
# [65]	validation_0-rmse:0.41435	validation_1-rmse:0.58643
# [66]	validation_0-rmse:0.41434	validation_1-rmse:0.58643
# [67]	validation_0-rmse:0.41433	validation_1-rmse:0.58643
# [68]	validation_0-rmse:0.41432	validation_1-rmse:0.58642
# [69]	validation_0-rmse:0.41431	validation_1-rmse:0.58641
# [70]	validation_0-rmse:0.41431	validation_1-rmse:0.58641
# [71]	validation_0-rmse:0.41430	validation_1-rmse:0.58641
# [72]	validation_0-rmse:0.41430	validation_1-rmse:0.58641
# [73]	validation_0-rmse:0.41429	validation_1-rmse:0.58641
# [74]	validation_0-rmse:0.41429	validation_1-rmse:0.58641
# [75]	validation_0-rmse:0.41428	validation_1-rmse:0.58641
# [76]	validation_0-rmse:0.41428	validation_1-rmse:0.58641
# [77]	validation_0-rmse:0.41427	validation_1-rmse:0.58639
# [78]	validation_0-rmse:0.41427	validation_1-rmse:0.58639
# [79]	validation_0-rmse:0.41426	validation_1-rmse:0.58639
# [80]	validation_0-rmse:0.41426	validation_1-rmse:0.58639
# [81]	validation_0-rmse:0.41425	validation_1-rmse:0.58638
# [82]	validation_0-rmse:0.41425	validation_1-rmse:0.58638
# [83]	validation_0-rmse:0.41424	validation_1-rmse:0.58638
# [84]	validation_0-rmse:0.41423	validation_1-rmse:0.58638
# [85]	validation_0-rmse:0.41423	validation_1-rmse:0.58638
# [86]	validation_0-rmse:0.41421	validation_1-rmse:0.58637
# [87]	validation_0-rmse:0.41421	validation_1-rmse:0.58638
# [88]	validation_0-rmse:0.41421	validation_1-rmse:0.58637
# [89]	validation_0-rmse:0.41420	validation_1-rmse:0.58637
# [90]	validation_0-rmse:0.41419	validation_1-rmse:0.58637
# [91]	validation_0-rmse:0.41419	validation_1-rmse:0.58633
# [92]	validation_0-rmse:0.41419	validation_1-rmse:0.58632
# [93]	validation_0-rmse:0.41418	validation_1-rmse:0.58632
# [94]	validation_0-rmse:0.41418	validation_1-rmse:0.58633
# [95]	validation_0-rmse:0.41417	validation_1-rmse:0.58632
# [96]	validation_0-rmse:0.41417	validation_1-rmse:0.58632
# [97]	validation_0-rmse:0.41416	validation_1-rmse:0.58632
# [98]	validation_0-rmse:0.41416	validation_1-rmse:0.58632
# [99]	validation_0-rmse:0.41415	validation_1-rmse:0.58631
# [100]	validation_0-rmse:0.41414	validation_1-rmse:0.58632
# [101]	validation_0-rmse:0.41414	validation_1-rmse:0.58631
# [102]	validation_0-rmse:0.41414	validation_1-rmse:0.58631
# [103]	validation_0-rmse:0.41414	validation_1-rmse:0.58631
# [104]	validation_0-rmse:0.41413	validation_1-rmse:0.58630
# [105]	validation_0-rmse:0.41413	validation_1-rmse:0.58630
# [106]	validation_0-rmse:0.41413	validation_1-rmse:0.58627
# [107]	validation_0-rmse:0.41412	validation_1-rmse:0.58627
# [108]	validation_0-rmse:0.41412	validation_1-rmse:0.58627
# [109]	validation_0-rmse:0.41411	validation_1-rmse:0.58627
# [110]	validation_0-rmse:0.41411	validation_1-rmse:0.58626
# [111]	validation_0-rmse:0.41411	validation_1-rmse:0.58626
# [112]	validation_0-rmse:0.41410	validation_1-rmse:0.58626
# [113]	validation_0-rmse:0.41410	validation_1-rmse:0.58626
# [114]	validation_0-rmse:0.41410	validation_1-rmse:0.58625
# [115]	validation_0-rmse:0.41409	validation_1-rmse:0.58626
# [116]	validation_0-rmse:0.41409	validation_1-rmse:0.58625
# [117]	validation_0-rmse:0.41409	validation_1-rmse:0.58625
# [118]	validation_0-rmse:0.41409	validation_1-rmse:0.58625
# [119]	validation_0-rmse:0.41408	validation_1-rmse:0.58625
# [120]	validation_0-rmse:0.41408	validation_1-rmse:0.58625
# [121]	validation_0-rmse:0.41408	validation_1-rmse:0.58625
# [122]	validation_0-rmse:0.41407	validation_1-rmse:0.58625
# [123]	validation_0-rmse:0.41407	validation_1-rmse:0.58625
# [124]	validation_0-rmse:0.41407	validation_1-rmse:0.58625
# [125]	validation_0-rmse:0.41406	validation_1-rmse:0.58625
# [126]	validation_0-rmse:0.41406	validation_1-rmse:0.58625
# [127]	validation_0-rmse:0.41406	validation_1-rmse:0.58625
# [128]	validation_0-rmse:0.41405	validation_1-rmse:0.58625
# [129]	validation_0-rmse:0.41405	validation_1-rmse:0.58625
# [130]	validation_0-rmse:0.41405	validation_1-rmse:0.58626

# %%
preds = trained_model.predict(X_test[['VAL. SIMULACAO', 'VALOR DE OBSERVACAO']].values)
mse_test = mean_squared_error(y_test, preds)
print(f'Test MSE: {mse_test}')
# Out:
# Test MSE: 0.2638229051413962

# %%
ERROR = y_test[:] - preds

ERROR_SMOOTH = signal.savgol_filter(ERROR, 99, 3, axis=0)

mean_error = ERROR.mean()
std_error = ERROR.std()

plt.figure()
plt.plot(y_test, label="y-original")
plt.plot(preds, label="y-predicted")
plt.legend()

plt.show()

print("Média de erro:", mean_error)
print("Desvio padrão", std_error)
# Out:
# Média de erro: 0.07597994995577455
# Desvio padrão 0.5079863273485926

# %%
#grava os resultados no arquivo .csv
results_model = X_test.copy()
results_model['target'] = y_test
results_model['predictions'] = preds
results_model.head()
# Out:
#          LAT       LONG  PONTO DE GRADE Y  PONTO DE GRADE X  VAL. SIMULACAO  \
# 0 -36.198620 -59.649200               1.0               1.0      280.371643
# 1 -36.202236 -59.549255               1.0               2.0      280.334778
# 2 -36.205776 -59.449310               1.0               3.0      280.300171
# 3 -36.209244 -59.349365               1.0               4.0      280.277283
# 4 -36.212631 -59.249420               1.0               5.0      280.279175
#
#    VALOR DE OBSERVACAO  MES  DIA     target  predictions
# 0           280.371643    8   16  279.86060   280.381042
# 1           280.334778    8   16  279.85074   280.296387
# 2           280.300171    8   16  279.83188   280.296387
# 3           280.277283    8   16  279.81973   280.296387
# 4           281.399990    8   16  279.79227   280.158417

# %%
results_model.to_csv('results.csv')

# %% [markdown]
# ##Visualização dos resultados

# %%
ativacao_dia_teste = results_model[(results_model['MES'] == 7) & (results_model['DIA'] == 6)]
ativacao_dia_teste.shape
# Out:
# (17931, 10)

# %%
lat = expand(ativacao_dia_teste, 'LAT', variavel='PONTO DE GRADE Y')
lat = pd.DataFrame(lat)

longi = expand(ativacao_dia_teste, 'LONG', variavel='PONTO DE GRADE Y')
longi = pd.DataFrame(longi)

# %%
rotulos = expand(ativacao_dia_teste, 'target', variavel='PONTO DE GRADE Y')
rotulos = pd.DataFrame(rotulos)

plot(longi, lat, rotulos, 'Análise 3DVar', x=(-58.9,-47.699), y=(-36.2,-25.1),
     figsize=(10,8.5))

# %%
preds = expand(ativacao_dia_teste, 'predictions', variavel='PONTO DE GRADE Y')
preds = pd.DataFrame(rotulos)

plot(longi, lat, preds, 'Análise XGBoost', x=(-58.9,-47.699), y=(-36.2,-25.1),
     figsize=(10,8.5))
