# %%
# %pip install myqlm
# Out:
# Collecting myqlm
#   Downloading myqlm-1.9.9-py3-none-any.whl (2.1 kB)
# Collecting qat-comm==1.4.7 (from myqlm)
#   Downloading qat_comm-1.4.7-cp310-cp310-manylinux_2_34_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.3 MB/s eta 0:00:00
# Collecting qat-core==1.8.5 (from myqlm)
#   Downloading qat_core-1.8.5-cp310-cp310-manylinux_2_34_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 34.1 MB/s eta 0:00:00
# Collecting qat-lang==3.0.4 (from myqlm)
#   Downloading qat_lang-3.0.4-cp310-cp310-manylinux_2_34_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 50.0 MB/s eta 0:00:00
# Collecting qat-devices==0.2.4 (from myqlm)
#   Downloading qat_devices-0.2.4-cp310-cp310-manylinux_2_34_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.9/269.9 kB 13.9 MB/s eta 0:00:00
# Collecting qat-variational==1.4.4 (from myqlm)
#   Downloading qat_variational-1.4.4-cp310-cp310-manylinux_2_34_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.7 MB/s eta 0:00:00
# Collecting qlmaas==1.10.1 (from myqlm)
#   Downloading qlmaas-1.10.1-cp310-cp310-manylinux_2_34_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 65.6 MB/s eta 0:00:00
# Collecting myqlm-clinalg==0.1.4 (from myqlm)
#   Downloading myqlm_clinalg-0.1.4-cp310-cp310-manylinux_2_34_x86_64.whl (578 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 kB 52.5 MB/s eta 0:00:00
# Collecting myqlm-contrib==1.9.3 (from myqlm)
#   Downloading myqlm_contrib-1.9.3-py3-none-any.whl (13 kB)
# Collecting myqlm-fermion==1.1.2 (from myqlm)
#   Downloading myqlm_fermion-1.1.2-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 kB 11.8 MB/s eta 0:00:00
# Collecting myqlm-simulators==1.9.4 (from myqlm)
#   Downloading myqlm_simulators-1.9.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from myqlm-contrib==1.9.3->myqlm) (3.2.1)
# Collecting anytree (from myqlm-fermion==1.1.2->myqlm)
#   Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 5.9 MB/s eta 0:00:00
# Collecting bitstring (from myqlm-fermion==1.1.2->myqlm)
#   Downloading bitstring-4.1.4-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from myqlm-fermion==1.1.2->myqlm) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from myqlm-fermion==1.1.2->myqlm) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from myqlm-fermion==1.1.2->myqlm) (4.66.1)
# Collecting thrift==0.16.0 (from qat-comm==1.4.7->myqlm)
#   Downloading thrift-0.16.0.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wand (from qat-core==1.8.5->myqlm)
#   Downloading Wand-0.6.13-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 15.2 MB/s eta 0:00:00
# Collecting dill (from qat-core==1.8.5->myqlm)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from qat-core==1.8.5->myqlm) (3.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from qat-core==1.8.5->myqlm) (9.4.0)
# Collecting svgwrite (from qat-core==1.8.5->myqlm)
#   Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: jax[cpu] in /usr/local/lib/python3.10/dist-packages (from qat-core==1.8.5->myqlm) (0.4.23)
# Collecting ply==3.11 (from qat-lang==3.0.4->myqlm)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.8 MB/s eta 0:00:00
# Collecting pyDOE (from qat-variational==1.4.4->myqlm)
#   Downloading pyDOE-0.3.8.zip (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: prompt-toolkit in /usr/local/lib/python3.10/dist-packages (from qlmaas==1.10.1->myqlm) (3.0.43)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from qlmaas==1.10.1->myqlm) (3.9.0)
# Requirement already satisfied: pyOpenSSL in /usr/local/lib/python3.10/dist-packages (from qlmaas==1.10.1->myqlm) (24.0.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from qlmaas==1.10.1->myqlm) (1.16.0)
# Collecting qat-hardware>=1.3.3 (from qlmaas==1.10.1->myqlm)
#   Downloading qat_hardware-1.3.4-cp310-cp310-manylinux_2_34_x86_64.whl (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.6/266.6 kB 22.2 MB/s eta 0:00:00
# Collecting qat-quops>=1.3.2 (from qlmaas==1.10.1->myqlm)
#   Downloading qat_quops-1.3.3-cp310-cp310-manylinux_2_34_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.6 MB/s eta 0:00:00
# Collecting dill (from qat-core==1.8.5->myqlm)
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from thrift==0.16.0->qat-comm==1.4.7->myqlm) (1.16.0)
# Collecting qutip (from qat-hardware>=1.3.3->qlmaas==1.10.1->myqlm)
#   Downloading qutip-4.7.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 45.3 MB/s eta 0:00:00
# Requirement already satisfied: cvxpy in /usr/local/lib/python3.10/dist-packages (from qat-quops>=1.3.2->qlmaas==1.10.1->myqlm) (1.3.3)
# Collecting bitarray<3.0.0,>=2.8.0 (from bitstring->myqlm-fermion==1.1.2->myqlm)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 28.0 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->qlmaas==1.10.1->myqlm) (2.21)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax[cpu]->qat-core==1.8.5->myqlm) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax[cpu]->qat-core==1.8.5->myqlm) (3.3.0)
# Requirement already satisfied: jaxlib==0.4.23 in /usr/local/lib/python3.10/dist-packages (from jax[cpu]->qat-core==1.8.5->myqlm) (0.4.23+cuda12.cudnn89)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->qat-core==1.8.5->myqlm) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->qat-core==1.8.5->myqlm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->qat-core==1.8.5->myqlm) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->qat-core==1.8.5->myqlm) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->qat-core==1.8.5->myqlm) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->qat-core==1.8.5->myqlm) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->qat-core==1.8.5->myqlm) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->qlmaas==1.10.1->myqlm) (0.2.13)
# Requirement already satisfied: cryptography<43,>=41.0.5 in /usr/local/lib/python3.10/dist-packages (from pyOpenSSL->qlmaas==1.10.1->myqlm) (42.0.2)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy->qat-quops>=1.3.2->qlmaas==1.10.1->myqlm) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy->qat-quops>=1.3.2->qlmaas==1.10.1->myqlm) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy->qat-quops>=1.3.2->qlmaas==1.10.1->myqlm) (3.2.4.post1)
# Requirement already satisfied: setuptools>65.5.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy->qat-quops>=1.3.2->qlmaas==1.10.1->myqlm) (67.7.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy->qat-quops>=1.3.2->qlmaas==1.10.1->myqlm) (0.1.7.post0)
# Building wheels for collected packages: thrift, pyDOE
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.16.0-cp310-cp310-linux_x86_64.whl size=373868 sha256=246b960e79da11842166feb658a95925139e579068a71c7041f412bce081c5c7
#   Stored in directory: /root/.cache/pip/wheels/52/f8/d2/acfd995e8247eb0cad372fa6a640a5fcf279ab2ed7c5c4490e
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18168 sha256=0a2889dd3a16f1251f87e7c8718a03f13805c5eec8448d9ed43d39d11745ac80
#   Stored in directory: /root/.cache/pip/wheels/ce/b6/d7/c6b64746dba6433c593e471e0ac3acf4f36040456d1d160d17
# Successfully built thrift pyDOE
# Installing collected packages: wand, ply, bitarray, thrift, svgwrite, dill, bitstring, anytree, qutip, qat-comm, pyDOE, qat-core, qat-lang, qat-devices, myqlm-contrib, qat-variational, qat-quops, qat-hardware, myqlm-clinalg, myqlm-simulators, qlmaas, myqlm-fermion, myqlm
# Successfully installed anytree-2.12.1 bitarray-2.9.2 bitstring-4.1.4 dill-0.3.5.1 myqlm-1.9.9 myqlm-clinalg-0.1.4 myqlm-contrib-1.9.3 myqlm-fermion-1.1.2 myqlm-simulators-1.9.4 ply-3.11 pyDOE-0.3.8 qat-comm-1.4.7 qat-core-1.8.5 qat-devices-0.2.4 qat-hardware-1.3.4 qat-lang-3.0.4 qat-quops-1.3.3 qat-variational-1.4.4 qlmaas-1.10.1 qutip-4.7.5 svgwrite-1.4.3 thrift-0.16.0 wand-0.6.13

# %% [markdown]
# $\newcommand{\ket}[1]{{\left\vert{#1}\right\rangle}}$
# $\newcommand{\bra}[1]{{\left\langle{#1}\right\vert}}$
# # Algoritmo de Grover
#
# Neste notebook, vamos apresentar o algoritmo Grover e implementar em `myQLM`.
#
# Material de apoio:
# - Capítulo 3 de https://proceedings.science/series/23/proceedings_non_indexed/13
# - Capítulo 7 de https://github.com/programaquantica/tutoriais/blob/master/programaquantica.pdf
# - Capítulo 9 de https://arxiv.org/abs/2201.10574
#
#
# ## Descrição do Algoritmo de Grover
# Seja $N=2^n$ para algum inteiro $n$ e suponha que $f:\big\{0,\ldots,N-1\big\}\rightarrow \{0,1\}$ seja uma função booleana tal que $f(x)=1$ se e somente se $ x=x_0$ para algum valor fixo $x_0$. A expressão matemática de $f(x)$ é
#
# \begin{equation*}\label{ag_f_x}
#     f(x) = \left\{
#   \begin{array}{l@{\quad}l}
#     1, & \hbox{se ${x=x_0}$,} \\
#     0, & \hbox{caso contrário.}
#   \end{array}
# \right.
# \end{equation*}
#
# Suponha que $x_0$ seja desconhecido. Como podemos encontrar $x_0$ avaliando $f$? Do ponto de vista computacional, queremos avaliar a função o menor número de vezes.
#
# Classicamente, o algoritmo mais eficiente consulta essa função $N$ vezes no pior caso. Usando um computador quântico, é possível melhorar o número de avaliações para $O(\sqrt N)$. Como é feito na prática? Temos que usar uma matriz unitária $U_{f}$ que implementa a função $f(x)$ em um computador quântico como um caixa preta. Podemos usar $U_{f}$, mas não podemos ver os detalhes da implementação de $U_{f}$. Cada vez que usamos $U_{f}$, adicionamos uma unidade à contagem.
#
#
#
# ## Operadores
# Consideramos um registrador de $n$ qubits de modo que um dos elementos da base computacional é dado por $|x_0\rangle$. Definimos inicialmente uma condição inicial uniforme
#
# $$|\psi_0\rangle =  \frac{1}{\sqrt{2^n}}\sum_{i=0}^{2^n-1} |x\rangle$$
#
# Daí, definimos os operadores:
#
# $$U_{f} \ket{x}\ket{i}=\ket{x}\ket{i\oplus f(x)},$$
# chamado de oráculo (codifica a função $f$), e
#
# $$G = (2|\psi_0\rangle\langle \psi_0| - \mathrm{I}_N)\otimes \mathrm{I}_2, $$
# chamado de operador de inversão em torno da média.
#
# ## Os passos do algoritmo
#
# O algoritmo tem os seguintes passos (usando $n+1$ qubits)
#
# 1. Primeiro, preparar o estado inicial $\ket{\psi_0}\ket{-}$;
#
# 2. Aplicar o operator $U_f$;
#
# 3. Aplicar o operator $G$;
#
# 4. Repetir $t$ vezes os passos 2 e 3 onde
#
# $$
# t=\left\lfloor\frac{\pi}{4}\sqrt N\right\rfloor;
# $$
#
# 5. Medir o primeiro registrador na base computacional.
#
# A medição retorna o estado $x_0$ com probabilidade de aproximadamente $1 - \frac{1}{\sqrt{N}}$.

# %% [markdown]
# ## Estudando o oráculo:
#
# ### Como implementar a caixa preta $U_f$?
#
# Como $f(x)$ é uma função booleana cuja tabela verdade possui uma única linha com saída 1, $f(x)$ pode ser implementada com uma porta Toffoli generalizada ativada por $x_0$ (veja a seção 2.7 de https://arxiv.org/abs/2201.10574). $U_{f}$ é definida como
#
# \begin{equation*}
#     U_{f} \ket{x}\ket{i}=\ket{x}\ket{i\oplus f(x)},
# \end{equation*}
#
# onde $x$ é uma cadeia de $n$-bit e $i$ é um bit. Observe que se tomarmos $i=0$, a equação anterior se reduz a
#
# \begin{equation*}
#     U_{f}\ket{x}\ket{0}=\left\{
#                              \begin{array}{l@{\quad}l}
#                                \ket{x_0}\ket{1}, & \hbox{se ${x=x_0}$,} \\
#                                \ket{x}\ket{0}, & \hbox{caso contrário,}
#                              \end{array}
#                            \right.
# \end{equation*}
#
# que descreve a saída de uma porta Toffoli generalizada ativada por $x_0$ (e somente por $x_0$) quando a entrada é $\ket{x}\ket{0}$. O resultado do cálculo de $f(x)$ é armazenado no segundo registrador enquanto o estado do primeiro registro permanece inalterado.
#
#
# Por exemplo, o circuito que implementa $U_{f}$ no caso $N=8$ e $x_0=6$, ou seja, $f(110)=1$ e $f(j)=0$ se $ j\neq 110$, é
#
# ![circ_Tofolli_1.png](data:image/png;base64,...)
#
# O primeiro registrador tem três qubits. Observe que o estado do segundo registro muda de $\ket{0}$ para $\ket{1}$ somente se a entrada para o primeiro registro for $\ket{110}$ porque 110 ativa os três controles e todos os outras cadeias de 3 bits não ativam.

# %%
from qat.lang import *
from qat.qpus import PyLinalg
import matplotlib.pyplot as plt
import math as m

# %%
x0 = (1,1,0,0,0)
n = len(x0)
oraculo = QRoutine()
fios = oraculo.new_wires(n+1)

for i,valor in enumerate(x0):
    if(valor ==0):
      oraculo.apply(X,i)

X.ctrl(n)(fios)

for i,valor in enumerate(x0):
    if(valor ==0):
      oraculo.apply(X,i)

oraculo.display()
# Out:
# <svg baseProfile="full" height="400" version="1.1" viewBox="0 0 179 293" width="1200" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><style type="text/css"><![CDATA[@font-face{
#     font-family: "STIXMathJax_Main-Italic";
#     src: url("data:application/x-font-opentype;charset=utf-8;base64,...");
# }
# ]]></style></defs><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="37">Q0</text><line stroke="rgb(0,0,0)" x1="50" x2="179" y1="32" y2="32" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="69">Q1</text><line stroke="rgb(0,0,0)" x1="50" x2="179" y1="64" y2="64" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="101">Q2</text><line stroke="rgb(0,0,0)" x1="50" x2="179" y1="96" y2="96" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="133">Q3</text><line stroke="rgb(0,0,0)" x1="50" x2="179" y1="128" y2="128" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="165">Q4</text><line stroke="rgb(0,0,0)" x1="50" x2="179" y1="160" y2="160" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="197">Q5</text><line stroke="rgb(0,0,0)" x1="50" x2="179" y1="192" y2="192" /><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="60" y="84" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="68" y="101">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="60" y="116" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="68" y="133">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="60" y="148" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="68" y="165">X</text><line stroke="rgb(0,0,0)" x1="110" x2="110" y1="192" y2="32" /><circle cx="110" cy="32" fill="black" r="4" /><line stroke="rgb(0,0,0)" x1="110" x2="110" y1="192" y2="64" /><circle cx="110" cy="64" fill="black" r="4" /><line stroke="rgb(0,0,0)" x1="110" x2="110" y1="192" y2="96" /><circle cx="110" cy="96" fill="black" r="4" /><line stroke="rgb(0,0,0)" x1="110" x2="110" y1="192" y2="128" /><circle cx="110" cy="128" fill="black" r="4" /><line stroke="rgb(0,0,0)" x1="110" x2="110" y1="192" y2="160" /><circle cx="110" cy="160" fill="black" r="4" /><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="97" y="180" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="105" y="197">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="134" y="84" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="142" y="101">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="134" y="116" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="142" y="133">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="134" y="148" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="142" y="165">X</text></svg>

# %% [markdown]
# ### Mas o que representa?
#
#
# No algoritmo de Grover, o estado do segundo registrador é sempre
#
# $$
# \ket{-}=\frac{\ket{0}-\ket{1}}{\sqrt 2}.
# $$
#
# Usando linearidade, a ação de $U_{f}$ é dada por
#
# \begin{equation*}
#     U_{f}\ket{x}\ket{-}=\left\{
#                              \begin{array}{l@{\quad}l}
#                                -\ket{x_0}\ket{-}, & \hbox{se ${x=x_0}$,} \\
#                                \,\,\,\,\ket{x}\ket{-}, & \hbox{caso contrário.}
#                              \end{array}
#                            \right.
# \end{equation*}
#
# Isto representa no primeiro registrador a aplicação de um operador $u$ que realiza $\textbf{uma reflexão em torno do espaço ortogonal à $\ket{x_0}$}$:
#
# ![u.png](data:image/png;base64,...)entrada é $\ket{x}\ket{0}$. O resultado do cálculo de $f(x)$ é armazenado no segundo registrador enquanto o estado do primeiro registro permanece inalterado.

# %% [markdown]
# ## Estudando o operador de inversão em torno da média
# ### Como implementar?
#
# Vamos começar decompondo o que ocorre no primeiro registrador na definição abaixo:
# $$G = (2|\psi_0\rangle\langle \psi_0| - \mathrm{I}_N)\otimes \mathrm{I}_2$$
#
# Sabendo que $|\psi_0\rangle = H^{\otimes n}|0\rangle$, temos:
# $$2|\psi_0\rangle\langle \psi_0| - \mathrm{I}_N = H^{\otimes n} (2|0\rangle\langle 0| - \mathrm{I}_N) H^{\otimes n}$$
#
# Logo, tudo que deve ocorrer no primeiro registrador é a inversão do sinal de $|0\rangle$ entre a aplicação de portas de Hadamard.
#
# Usamos o fato do segundo registrador estar sempre no estado $|-\rangle$ para implementar $(2|0\rangle\langle 0| - \mathrm{I}_N)$ da forma:

# %% [markdown]
# ![inversao0.png](data:image/png;base64,...)

# %%
G = QRoutine()
fios_G = G.new_wires(n+1)

for i in range(n):
  G.apply(H,i)
  G.apply(X,i)

G.apply(X.ctrl(n),fios_G)

for i in range(n):
  G.apply(X,i)
  G.apply(H,i)

G.display()
# Out:
# <svg baseProfile="full" height="400" version="1.1" viewBox="0 0 257 293" width="1200" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><style type="text/css"><![CDATA[@font-face{
#     font-family: "STIXMathJax_Main-Italic";
#     src: url("data:application/x-font-opentype;charset=utf-8;base64,...");
# }
# ]]></style></defs><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="37">Q0</text><line stroke="rgb(0,0,0)" x1="50" x2="257" y1="32" y2="32" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="69">Q1</text><line stroke="rgb(0,0,0)" x1="50" x2="257" y1="64" y2="64" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="101">Q2</text><line stroke="rgb(0,0,0)" x1="50" x2="257" y1="96" y2="96" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="133">Q3</text><line stroke="rgb(0,0,0)" x1="50" x2="257" y1="128" y2="128" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="165">Q4</text><line stroke="rgb(0,0,0)" x1="50" x2="257" y1="160" y2="160" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="10" y="197">Q5</text><line stroke="rgb(0,0,0)" x1="50" x2="257" y1="192" y2="192" /><rect fill="white" height="24" stroke="black" stroke-width="2" width="29" x="60" y="20" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="68" y="37">H</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="29" x="60" y="52" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="68" y="69">H</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="29" x="60" y="84" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="68" y="101">H</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="29" x="60" y="116" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="68" y="133">H</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="29" x="60" y="148" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="68" y="165">H</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="99" y="20" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="107" y="37">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="99" y="52" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="107" y="69">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="99" y="84" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="107" y="101">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="99" y="116" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="107" y="133">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="99" y="148" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="107" y="165">X</text><line stroke="rgb(0,0,0)" x1="149" x2="149" y1="192" y2="32" /><circle cx="149" cy="32" fill="black" r="4" /><line stroke="rgb(0,0,0)" x1="149" x2="149" y1="192" y2="64" /><circle cx="149" cy="64" fill="black" r="4" /><line stroke="rgb(0,0,0)" x1="149" x2="149" y1="192" y2="96" /><circle cx="149" cy="96" fill="black" r="4" /><line stroke="rgb(0,0,0)" x1="149" x2="149" y1="192" y2="128" /><circle cx="149" cy="128" fill="black" r="4" /><line stroke="rgb(0,0,0)" x1="149" x2="149" y1="192" y2="160" /><circle cx="149" cy="160" fill="black" r="4" /><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="136" y="180" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="144" y="197">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="173" y="20" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="181" y="37">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="173" y="52" /><text style="font-family: STIXMathJax_Main-Italic; font-size: 16px;" x="181" y="69">X</text><rect fill="white" height="24" stroke="black" stroke-width="2" width="27" x="173" y="84" /><text style="font-family: STIXMathJax_ ...

# %% [markdown]
# ### O que representa?
#
# A ação do operador $G$ seguida do $U_f$ no estado inicial roda o vetor $\ket{\psi_0}$ no sentido anti-horário. O ângulo de rotação é $\theta$.

# %% [markdown]
# ![g.png](data:image/png;base64,...)

# %% [markdown]
# ## Resultado final:
#
# Cada iteração do passo de Grover faz uma rotação do vetor atual de $\theta$ graus em direção ao $\ket{x_0}$. Utilizamos um número $t$ de iterações que dê
# $$t\theta \approx \frac{\pi}{2}$$
# Deste modo, o estado final é tão próximo de $\ket{x_0}$ quanto era de $\ket{x_0}^\perp$ no início da execução. Note que errar o número de passos irá fazer nosso estado se afastar de $\ket{x_0}$.

# %%
N = 2**n
t_opt = m.floor(m.pi*m.sqrt(N)/4)
print('Número ótimo de repetições:',t_opt)

prog = Program()
Qr = prog.qalloc(n+1)

#inicializar em |psi_0>|->
for i in range(n):
    prog.apply(H,i)
prog.apply(X,n)
prog.apply(H,n)

probs = []
repeticoes = []
for i in range(t_opt*2-1):
  prog.apply(oraculo,Qr)
  prog.apply(G,Qr)

  simulador = PyLinalg()
  circuito = prog.to_circ()
  job = circuito.to_job()
  result = simulador.submit(job)
  repeticoes.append(i+1)
  prob =0
  for sample in result:
    if ('|' + ''.join(map(str,x0)) in str(sample.state)):
      prob+=sample.probability
  probs.append(prob)
# Out:
# Número ótimo de repetições: 4

# %%
plt.plot(repeticoes,probs)

# %% [markdown]
# # Exercícios
#
# 1. Estenda o algoritmo de Grover para mais do que 1 elemento marcado. Suponha que o número de elementos marcados seja $m$. Modifique apenas o operdor $U_f$ usando uma porta Toffoli multiqubit para cada elemento marcado. Faça uma implementação que mostre que tempo de execução ideal é $\left\lfloor\frac{\pi}{4}\sqrt{\frac{N}{m}}\right\rfloor$.
#
# 2. Implemente o algoritmo de Grover sem usar o segundo registrador. Use Capítulo 9 Seção 9.5 de https://arxiv.org/abs/2201.10574.
